# %%
from importData import importData
from assignment2_functions import plot_raster
import matplotlib.pyplot as plt

D = importData()
D = D[4]
n = 3
t= 1
figH = plt.figure(0)
for i in range(0, 4): # loop on 4 different conditions
    c = 6+2*i # condition
    plot_raster(D['spikes'][n, c, :, :], D['times'], figH, 411+i)
    print('plotted raster for condition ' + str(c) + ' : ' + str (D['conditions'][c]))
plt.xlabel('Time (ms)')
plt.ylabel('Trial')


from assignment2_functions import plot_simple_psth, plot_psth
figH1 = plt.figure(1)
figH5 = plt.figure(2)
for i in range(0, 4): # loop over 4 different conditions
    c = 3+2*i
    plot_simple_psth(D['spikes'][n, c, :, :], D['times'], figH1, 411+i)
    plot_psth(D['spikes'][n, c, :, :], 5, D['times'], figH5, 411+i)
    print('plotted PSTH for condition ' + str(c) + ' : ' + str (D['conditions'][c]))
plt.xlabel('Time (ms)')


#plot_simple_psth(D['spikes']/['times'][n, c, :, :], D['times'], figH1, 411+i)
#plot_psth(D['spikes']/['times'][n, c, :, :], 5, D['times'], figH5, 411+i)
#print('plotted PSTH for condition ' + str(c) + ' : ' + str (D['conditions'][c]))
#plt.xlabel('Time (ms)')#


#//plot_simple_psth(D['spikes'/'times'][n, c, :, :], D['times'], figH1, 411+i)
#plot_psth(D['spikes'/'times'][n, c, :, :], 5, D['times'], figH5, 411+i)#
#print('plotted PSTH for condition ' + str(c) + ' : ' + str (D['conditions'][c]))
#plt.xlabel('Time (ms)')#
figH2 = plt.figure(3)
figH6 = plt.figure(4)
#plot_simple_psth(D['spikes'][n, c, t, :], D['times'],figH2, 411+i)
#plot_psth(D['spikes'][n, c, t, :], D['times'], figH6, 411+i)
#print('plotted PSTH for condition ' + str(c) + ' : ' + str (D['conditions'][c]))
#plt.xlabel('Time (ms)')

plot_simple_psth(D['spikes'][n, c, :, :], D['orientation'], figH2, 411+i)
plot_psth(D['spikes'][n, c, :, :], D['orientation'],figH6, 411+i)
print('plotted PSTH for condition ' + str(c) + ' : ' + str (D['conditions'][c]))
plt.xlabel('Time (ms)')
# Out:
# plotted raster for condition 6 : {'contrast': 1, 'orientation': 67.5}
# plotted raster for condition 8 : {'contrast': 1, 'orientation': 90}
# plotted raster for condition 10 : {'contrast': 1, 'orientation': 112.5}
# plotted raster for condition 12 : {'contrast': 1, 'orientation': 135}
# plotted PSTH for condition 3 : {'contrast': 10, 'orientation': 22.5}
# plotted PSTH for condition 5 : {'contrast': 10, 'orientation': 45}
# plotted PSTH for condition 7 : {'contrast': 10, 'orientation': 67.5}
# plotted PSTH for condition 9 : {'contrast': 10, 'orientation': 90}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-e99813b635c1> in <module>
#      44 #plt.xlabel('Time (ms)')
#      45
# ---> 46 plot_simple_psth(D['spikes'][n, c, :, :], D['orientation'], figH2, 411+i)
#      47 plot_psth(D['spikes'][n, c, :, :], D['orientation'],figH6, 411+i)
#      48 print('plotted PSTH for condition ' + str(c) + ' : ' + str (D['conditions'][c]))
#
# KeyError: 'orientation'
